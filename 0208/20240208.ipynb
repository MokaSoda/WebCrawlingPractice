# %%
from urllib.request import Request
from urllib.request import urlopen
from urllib.error import *

import aiohttp
# from urllib import the module which can opem website

from bs4 import BeautifulSoup

# %%
html_text = '<span class="red">Heavens! what a virulent attack!</span>'

# %%
soup = BeautifulSoup(html_text, 'lxml')
object_tag = soup.select_one('span')
print('object_tag', object_tag)
print('attrs:', object_tag.attrs)
print('values:', object_tag.attrs['class'])
print('text: ', object_tag.text)
# Out:
# object_tag <span class="red">Heavens! what a virulent attack!</span>
# attrs: {'class': ['red']}
# values: ['red']
# text:  Heavens! what a virulent attack!

# %%
html_green = urlopen('https://www.pythonscraping.com/pages/warandpeace.html')
soup = BeautifulSoup(html_green, 'lxml')

nameList = soup.select('span.green')
for name in nameList:
    print(" ".join(name.string.split('\n')))
# Out:
# Anna Pavlovna Scherer
# Empress Marya Fedorovna
# Prince Vasili Kuragin
# Anna Pavlovna
# St. Petersburg
# the prince
# Anna Pavlovna
# Anna Pavlovna
# the prince
# the prince
# the prince
# Prince Vasili
# Anna Pavlovna
# Anna Pavlovna
# the prince
# Wintzingerode
# King of Prussia
# le Vicomte de Mortemart
# Montmorencys
# Rohans
# Abbe Morio
# the Emperor
# the prince
# Prince Vasili
# Dowager Empress Marya Fedorovna
# the baron
# Anna Pavlovna
# the Empress
# the Empress
# Anna Pavlovna's
# Her Majesty
# Baron Funke
# The prince
# Anna Pavlovna
# the Empress
# The prince
# Anatole
# the prince
# The prince
# Anna Pavlovna
# Anna Pavlovna

# %%
ListofPrince = soup.findAll(string ='the prince')
ListofPrince
# Out:
# ['the prince',
#  'the prince',
#  'the prince',
#  'the prince',
#  'the prince',
#  'the prince',
#  'the prince']

# %%
# count of the prince
print('the prince count:',len(ListofPrince))
# Out:
# the prince count: 7

# %%
# children 갯수 조회
import requests

soup = BeautifulSoup(requests.get("https://www.pythonscraping.com/pages/page3.html").content,'lxml')

table_tag = soup.select_one('table#giftList')
print("children 갯수: ", len(list(table_tag.children)))
for child in table_tag.children:
    print(child)
    print("----------------------")
# Out:
# children 갯수:  13
#
#
# ----------------------
# <tr><th>
# Item Title
# </th><th>
# Description
# </th><th>
# Cost
# </th><th>
# Image
# </th></tr>
# ----------------------
#
#
# ----------------------
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
# ----------------------
#
#
# ----------------------
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
# ----------------------
#
#
# ----------------------
# ...

# %%
desc = soup.select_one('table#giftList').descendants
list_desc = list(desc)
print("descendants 갯수: ", len(list_desc))

for tag in list_desc:
    print(tag)
# Out:
# descendants 갯수:  86
#
#
# <tr><th>
# Item Title
# </th><th>
# Description
# </th><th>
# Cost
# </th><th>
# Image
# </th></tr>
# <th>
# Item Title
# </th>
#
# Item Title
#
# <th>
# Description
# </th>
#
# Description
#
# <th>
# Cost
# </th>
#
# Cost
#
# <th>
# Image
# </th>
#
# Image
#
#
#
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
# <td>
# Vegetable Basket
# </td>
#
# Vegetable Basket
#
# <td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td>
#
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
#
# ...

# %%
import aiohttp
async with aiohttp.ClientSession() as session:
    result = await session.get('https://www.pythonscraping.com/pages/page3.html')
    content = await result.content.read()

soup = BeautifulSoup(content, 'lxml')

for sibiling in soup.select_one('table#giftList').tr.next_siblings:
    print(sibiling)
# Out:
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift3"><td>
# Fish Painting
# </td><td>
# If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
# </td><td>
# $10,005.00
# </td><td>
# <img src="../img/gifts/img3.jpg"/>
# </td></tr>
#
#
# ...

# %%
sibling1 = soup.select_one('tr#gift3').next_sibling
print('sibling1: ', sibling1)
print(ord(sibling1))
# Out:
# sibling1:
#
# 10

# %%
sibling2 = soup.select_one('tr#gift3').next_sibling.next_sibling
print(sibling2)
# Out:
# <tr class="gift" id="gift4"><td>
# Dead Parrot
# </td><td>
# This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
# </td><td>
# $0.50
# </td><td>
# <img src="../img/gifts/img4.jpg"/>
# </td></tr>

# %%
img1 = soup.select_one("img[src='../img/gifts/img1.jpg']")
img1
# Out:
# <img src="../img/gifts/img1.jpg"/>

# %%
img1.parent
# Out:
# <td>
# <img src="../img/gifts/img1.jpg"/>
# </td>

# %%
img1.parent.previous_sibling.get_text()
# Out:
# '\n$15.00\n'

# %% [markdown]
# ## 정규식 사용

# %%
import re

m = re.match('[a-z]+', 'python')
print(m)
print(re.search('apple', 'I like apple'))
# Out:
# <re.Match object; span=(0, 6), match='python'>
# <re.Match object; span=(7, 12), match='apple'>

# %%
p = re.compile(r'[a-z]+')
p.match('python')
# Out:
# <re.Match object; span=(0, 6), match='python'>

# %%
[x for x in p.finditer('I like apple 123')]
# Out:
# [<re.Match object; span=(2, 6), match='like'>,
#  <re.Match object; span=(7, 12), match='apple'>]

# %%
re.match(r'[a-z]+', 'pythoN')
# Out:
# <re.Match object; span=(0, 5), match='pytho'>

# %%
print(re.match('[a-z]+', 'PYthon'))
# Out:
# None

# %%
# 뛰어쓰기는 검색에 영향을 줌
print(re.match('[a-z]+', 'regex python'))
print(re.match('[a-z]+', ' regexpython'))
# Out:
# <re.Match object; span=(0, 5), match='regex'>
# None

# %%
# 일반조건에서는 대문자 전까지 검색됨
re.match('[a-z]+', 'regexpythoN')
# Out:
# <re.Match object; span=(0, 10), match='regexpytho'>

# %%
# 마지막이 대문자이므로 끝 조건 만족이 안됨
print(re.match('[a-z]+$', 'regexpythonN'))
# Out:
# None

# %%
# 아니더라도 대문자전까지 검색
re.match('[a-z]+', 'regexPython')
# Out:
# <re.Match object; span=(0, 5), match='regex'>

# %%
# 모두 소문자가 아닌 경우 None
print(re.match('[a-z]+$', 'regexPython'))
# Out:
# None

# %%
p = re.compile('[a-z]+')

print(p.findall('life is too short! Regular expression test'))
# Out:
# ['life', 'is', 'too', 'short', 'egular', 'expression', 'test']

# %%
# search 함수 >> 일치하는 첫 문자열만 리턴
result = p.search('I like apple 123')
print(result)
print(result.group()) # group은 일치하는 전체 문자열을 출력해준다.

result = p.findall('I like apple 123')
print(result)
# Out:
# <re.Match object; span=(2, 6), match='like'>
# like
# ['like', 'apple']

# %%
tel_checker = re.compile('^(\d{2,3})-(\d{3,4})-(\d{4})$')

print(tel_checker.match('02-123-4567'))
print(tel_checker.match('053-950-45678'))
print(tel_checker.match('053950-3456'))
# Out:
# <re.Match object; span=(0, 11), match='02-123-4567'>
# None
# None

# %%
tel_checker
m = tel_checker.match('02-123-4567')

print(m.groups())
print(m.group())
print(m.group(0))
print(m.group(1))
print(m.group(1,2,3))
print(m.start())
print(m.end()) #매칭된 문자열의 마지막 인덱스 + 1
# Out:
# ('02', '123', '4567')
# 02-123-4567
# 02-123-4567
# 02
# ('02', '123', '4567')
# 0
# 11

# %%
cellphone = re.compile('^(01(?:0|1|[6-9]))-(\d{3,4})-(\d{4})$')

# %%
print(cellphone.match('010-123-4567'))
print(cellphone.match('019-1234-5678'))
print(cellphone.match('001-123-4567'))
print(cellphone.match('010-1234567'))
# Out:
# <re.Match object; span=(0, 12), match='010-123-4567'>
# <re.Match object; span=(0, 13), match='019-1234-5678'>
# None
# None

# %%
lookahead1 = re.search('.+(?=won)', '1000 won')
if lookahead1:
    print(lookahead1.group())
else:
    print('None')
# Out:
# 1000

# %%
lookahead2 = re.search('.+(?=am)', '2023-01-01 am 10:00:00')
lookahead2
# Out:
# <re.Match object; span=(0, 11), match='2023-01-01 '>

# %%
lookahead3 = re.search('\d{4}(?!-)', '010-1234-5678')
lookahead3
# Out:
# <re.Match object; span=(9, 13), match='5678'>

# %%
lookahead11 = re.search('\d{3}(?=-)', '010-1234-5678')
lookahead11
# Out:
# <re.Match object; span=(0, 3), match='010'>

# %%
lookbehind1 = re.search('(?<=am).+', '2023-01-01 am 10:00:00')
lookbehind1
# Out:
# <re.Match object; span=(13, 22), match=' 10:00:00'>

# %%
lookbehind2 = re.search('(?<=:).+', 'USD: $51')
lookbehind2
# Out:
# <re.Match object; span=(4, 8), match=' $51'>

# %%
lookbehind4 = re.search(r'\b(?<!\$)\d+\b', 'I paid $30 for 100 apples')
lookbehind4
# Out:
# <re.Match object; span=(15, 18), match='100'>

# %%
img_tag = re.compile('/img/gifts/img.*.jpg')

images = soup.findAll('img',{'src':img_tag})
soup
for image in images:
    print(image, end = " -> ['src'] 속성 :")
    print(image['src'])
# Out:
# <img src="../img/gifts/img1.jpg"/> -> ['src'] 속성 :../img/gifts/img1.jpg
# <img src="../img/gifts/img2.jpg"/> -> ['src'] 속성 :../img/gifts/img2.jpg
# <img src="../img/gifts/img3.jpg"/> -> ['src'] 속성 :../img/gifts/img3.jpg
# <img src="../img/gifts/img4.jpg"/> -> ['src'] 속성 :../img/gifts/img4.jpg
# <img src="../img/gifts/img6.jpg"/> -> ['src'] 속성 :../img/gifts/img6.jpg

# %%
import aiohttp
async with aiohttp.ClientSession() as session:
    result = await session.get('https://www.pythonscraping.com/pages/warandpeace.html')
    content_prince = await result.content.read()
soup_prince = BeautifulSoup(content_prince, 'lxml')
ListofPrince = soup_prince.findAll(text='the prince')
print("the prince count: ", len(ListofPrince))
# Out:
# the prince count:  7
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1052\3422740087.py:6: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   ListofPrince = soup_prince.findAll(text='the prince')

# %%
AllListofPrince = soup_prince.findAll(text=re.compile('[T|t]{1}he prince'))
print("T|the prince count:", len(AllListofPrince))
# Out:
# T|the prince count: 11
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1052\558865410.py:1: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   AllListofPrince = soup_prince.findAll(text=re.compile('[T|t]{1}he prince'))

# %%
import requests

header = {
    #latest firefox user agent
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:102.0) Gecko/20100101 Firefox/102.0',
        'Accept-language': 'en-US,en;q=0.5'
        #more headers here
}
html = requests.get('https://en.wikipedia.org/wiki/Kevin_Bacon', headers=header)
bs = BeautifulSoup(html.content, 'lxml')
for link in bs.findAll('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Early_life_and_education
# #Acting_career
# #Early_work
# #1980s
# #1990s
# #2000s
# #2010s
# #Other_ventures
# #Six_Degrees_of_Kevin_Bacon
# ...

# %%
divmain = bs.select_one('div#bodyContent')

pattern = '^(/wiki/)((?!:).)*$'
re.compile('^(/wiki/)((?!:).)*$')

for link in divmain.findAll('a', href=re.compile(pattern)):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Leading_man
# /wiki/Character_actor
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Footloose_(1984_film)
# /wiki/Diner_(1982_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Tremors_(1990_film)
# /wiki/The_River_Wild
# /wiki/The_Woodsman_(2004_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Michael_Strobl
# ...

# %%
import random

random.seed(None)


def getLinks(url):
    html = requests.get("https://en.wikipedia.org" + url)
    bs = BeautifulSoup(html.content, 'lxml')
    bodyContent = bs.select_one('div#bodyContent')
    wikiUrls = bodyContent.findAll('a', href=re.compile('^(/wiki/)((?!:).)*$'))
    return wikiUrls

links = getLinks('/wiki/Kevin_Bacon')
print(f"links 길이 : {len(links)}")
i = 0
while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs['href']
    print(newArticle)
    links = getLinks(newArticle)
    i += 1
    if i > 10:
        break
# Out:
# links 길이 : 437
# /wiki/Evan_Peters
# /wiki/Michael_Fassbender
# /wiki/British_Independent_Film_Awards
# /wiki/British_Society_of_Cinematographers
# /wiki/Ryan%27s_Daughter
# /wiki/The_French_Connection_(film)
# /wiki/Marty_(film)
# /wiki/Farewell_My_Concubine_(film)
# /wiki/Pan%27s_Labyrinth
# /wiki/Ariel_Award_for_Best_Supporting_Actor
# /wiki/The_Golden_Dream
# /wiki/Drama_film
# /wiki/List_of_ninja_films
# /wiki/Do_or_Die_(1991_film)
# /wiki/Pat_Morita
# /wiki/The_Fresh_Prince_of_Bel-Air
# /wiki/Young_Artist_Awards
# /wiki/36th_Young_Artist_Awards
# /wiki/Odd_Squad_(TV_series)
# /wiki/Parents%27_Choice_Award
# /wiki/Non-profit
# /wiki/Altruism
# /wiki/Doi_(identifier)
# /wiki/Unicode
# /wiki/Apple_Computer
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[174], line 18
#      16 newArticle = links[random.randint(0, len(links)-1)].attrs['href']
# ...

# %%
pages = set()
count = 0
def getLinks(url):
    global pages
    global count
    html = requests.get("https://en.wikipedia.org" + url)
    bs = BeautifulSoup(html.content, 'lxml')
    for link in bs.findAll('a', href=re.compile('^(/wiki/)((?!:).)*$')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                newPage = link.attrs['href']
                count += 1
                print(f"[{count}]: {newPage}")
                pages.add(newPage)
                getLinks(newPage)
    if count > 10:
        return 0

# getLinks('')

# %%
pages = set()
count = 0 
def getLinks_Text(url):
    global pages
    global  count
    html = requests.get('https://en.wikipedia.org'+ url)
    bs = BeautifulSoup(html.content, 'lxml')
    try:
        print(bs.select_one('h1').get_text())
        print(bs.select_one('#mw-content-text p').get_text())
    except AttributeError as e:
        print("this page is missing something! Continuing: e", e)
        
    for link in bs.findAll('a', href = re.compile('^(/wiki/)((?!:).)*$')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                newPage = link.attrs['href']
                print('-'*40)
                count += 1
                print(f"[{count}]: {newPage}")
                pages.add(newPage)
                getLinks_Text(newPage)

# getLinks_Text('')

# %%
query = 'ChatGPT'
url = f'https://search.naver.com/search.naver?where=view&sm=tab_jum&query={query}'

html = requests.get(url)
soup = BeautifulSoup(html.content, 'lxml')
blog_results = soup.select('a.title_link')

for blog_title in blog_results:
    title = blog_title.get_text()
    link = blog_title['href']
    print(f"{title}, [{link}]")
# Out:
# ChatGPT4에서 DALL-E 3 사용해 보기, [https://www.internetmap.kr/entry/DALL-E-3-in-ChatGPT4]
# ChatGPT 강의 챗봇 활용법 유데미 Udemy 추천 :), [https://blog.naver.com/sounds_cape/223337791018]
# 친구가 암에 걸렸다고 하는데, 뭐라고 위로해야 하는지를 ChatGPT에게 물어봤습니다., [https://blog.naver.com/lunar1st/223345405018]
# ChatGPT와 개러지밴드로 미디 작곡을~ 새로운 세상을 꿈꾸며, [https://blog.naver.com/senshig/223344793333]
# 된다하루만에끝내는챗GPT활용법으로 ChatGPT 사용법 쉽게 익히기, [https://blog.naver.com/sunzooland/223337757873]
# 폭스바겐, AI 챗봇 ChatGPT 통합한 8세대 골프 부분 변경 모델 공개, [https://post.naver.com/viewer/postView.naver?volumeNo=37242018&memberNo=32414000&vType=VERTICAL]
# 넷플릭스, 유튜브, ChatGPT Plus 4.0 할인 받기 OTT 공유: 고잉버스 goingbus, [https://blog.naver.com/chrisloi/223346293623]
# "커피 주문할게요" 영어로 어떻게? 해외여행 영어회화 ChatGPT로 해결!, [https://post.naver.com/viewer/postView.naver?volumeNo=37249739&memberNo=47129033&vType=VERTICAL]
# ChatGPT, 유럽 개인정보 위반 혐의, [https://blog.naver.com/thefirstrain/223338585200]
# ...
